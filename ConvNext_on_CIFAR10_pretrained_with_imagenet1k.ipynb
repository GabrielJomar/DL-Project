# %% [markdown]
# ##Finetuning the ConvNeXt  model pre trained on ImageNet 1K dataset.
# 1. Install necessary libraries.
# 2.Download Pretrained model. (https://dl.fbaipublicfiles.com/convnext/convnext_tiny_1k_224_ema.pth)This is a pytorch file.
# 3.Download data( Format to store dataset is mentioned in the Report)
# 4.Train

# %%
# !pip install -qq torch==1.8.0+cu111 torchvision==0.9.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install -qq wandb timm==0.4.11 six tensorboardX
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==1.8.0+cu111 (from versions: 1.11.0, 1.11.0+cpu, 1.11.0+cu102, 1.11.0+cu113, 1.11.0+cu115, 1.11.0+rocm4.3.1, 1.11.0+rocm4.5.2, 1.12.0, 1.12.0+cpu, 1.12.0+cu102, 1.12.0+cu113, 1.12.0+cu116, 1.12.0+rocm5.0, 1.12.0+rocm5.1.1, 1.12.1, 1.12.1+cpu, 1.12.1+cu102, 1.12.1+cu113, 1.12.1+cu116, 1.12.1+rocm5.0, 1.12.1+rocm5.1.1, 1.13.0, 1.13.0+cpu, 1.13.0+cu116, 1.13.0+cu117, 1.13.0+cu117.with.pypi.cudnn, 1.13.0+rocm5.1.1, 1.13.0+rocm5.2, 1.13.1, 1.13.1+cpu, 1.13.1+cu116, 1.13.1+cu117, 1.13.1+cu117.with.pypi.cudnn, 1.13.1+rocm5.1.1, 1.13.1+rocm5.2, 2.0.0, 2.0.0+cpu, 2.0.0+cpu.cxx11.abi, 2.0.0+cu117, 2.0.0+cu117.with.pypi.cudnn, 2.0.0+cu118, 2.0.0+rocm5.3, 2.0.0+rocm5.4.2, 2.0.1, 2.0.1+cpu, 2.0.1+cpu.cxx11.abi, 2.0.1+cu117, 2.0.1+cu117.with.pypi.cudnn, 2.0.1+cu118, 2.0.1+rocm5.3, 2.0.1+rocm5.4.2, 2.1.0, 2.1.0+cpu, 2.1.0+cpu.cxx11.abi, 2.1.0+cu118, 2.1.0+cu121, 2.1.0+cu121.with.pypi.cudnn, 2.1.0+rocm5.5, 2.1.0+rocm5.6)
# ...

# %%
# !git clone https://github.com/facebookresearch/ConvNeXt
# Out:
# Cloning into 'ConvNeXt'...
# remote: Enumerating objects: 252, done.
# remote: Counting objects: 100% (249/249), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 252 (delta 129), reused 193 (delta 111), pack-reused 3
# Receiving objects: 100% (252/252), 69.37 KiB | 8.67 MiB/s, done.
# Resolving deltas: 100% (129/129), done.

# %% [markdown]
# #Dataset

# %%
# !git clone https://github.com/YoongiKim/CIFAR-10-images
# Out:
# Cloning into 'CIFAR-10-images'...
# remote: Enumerating objects: 60027, done.
# remote: Total 60027 (delta 0), reused 0 (delta 0), pack-reused 60027
# Receiving objects: 100% (60027/60027), 19.94 MiB | 16.00 MiB/s, done.
# Resolving deltas: 100% (59990/59990), done.
# Updating files: 100% (60001/60001), done.

# %% [markdown]
# # Pretrained Model on ImageNet 1K dataset.

# %%
# %cd ConvNeXt/
# !wget https://dl.fbaipublicfiles.com/convnext/convnext_tiny_1k_224_ema.pth
# Out:
# /content/ConvNeXt
# --2023-10-25 08:26:44--  https://dl.fbaipublicfiles.com/convnext/convnext_tiny_1k_224_ema.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 52.84.251.15, 52.84.251.27, 52.84.251.114, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|52.84.251.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 114414741 (109M) [binary/octet-stream]
# Saving to: ‘convnext_tiny_1k_224_ema.pth’
#
# convnext_tiny_1k_22 100%[===================>] 109.11M   188MB/s    in 0.6s
#
# 2023-10-25 08:26:45 (188 MB/s) - ‘convnext_tiny_1k_224_ema.pth’ saved [114414741/114414741]

# %%
# !python main.py --epochs 20 \
                --model convnext_tiny \
                --data_set image_folder \
                --data_path ../CIFAR-10-images/train \
                --eval_data_path ../CIFAR-10-images/test \
                --nb_classes 10 \
                --num_workers 8 \
                --warmup_epochs 0 \
                --save_ckpt true \
                --output_dir model_ckpt \
                --finetune convnext_tiny_1k_224_ema.pth \
                --cutmix 0 \
                --mixup 0 --lr 4e-4 \
# Out:
# Not using distributed mode
# ...
